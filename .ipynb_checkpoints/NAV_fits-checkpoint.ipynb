# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
from scipy.optimize import curve_fit
from scipy.special import i0,i1,k0,k1
from scipy.constants import G
from scipy.constants import parsec as pc

# %%
msun=1.989e+30
kpc=1e+3*pc

# %%
column_names=["Rad","Vobs","errV","Vgas","Vdisk","Vbul","SBdisk","SBbul"]
dir="/home/esha/Documents/anurag"
df_list=[]
for gal in os.listdir(dir):
    #print(gal)
    if gal.endswith('.csv'):
        file_path=os.path.join(dir,gal)
        #print(file_path)
        df_gal=pd.read_csv(file_path,names=column_names)
        df_gal['Galaxy']=os.path.splitext(gal)[0]
        df_list.append(df_gal)
combined_df=pd.concat(df_list,ignore_index=True)

# %%
for column in column_names:
    combined_df[column]=pd.to_numeric(combined_df[column],errors='coerce')

# %%
combined_df[combined_df.isna().any(axis=1)]
# Out:
#     Rad  Vobs  errV  Vgas  Vdisk  Vbul  SBdisk  SBbul   Galaxy
# 74  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 75  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 76  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 77  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 78  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 79  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 80  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 81  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 82  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit
# 83  NaN   NaN   NaN   NaN    NaN   NaN     NaN    NaN  nfw_fit

# %%
uniq_gal=combined_df['Galaxy'].unique()
colors=plt.cm.rainbow(np.linspace(0,1,len(uniq_gal)))
plt.figure(figsize=(10,5))
for galaxy,color in zip(uniq_gal,colors):
    galaxy_data=combined_df[combined_df['Galaxy']==galaxy]
    plt.scatter(galaxy_data['Rad'],galaxy_data['Vobs'],color=color)
plt.xlabel("r(kpc)")
plt.ylabel("Vobs(km/s)")
# Out:
# Text(0, 0.5, 'Vobs(km/s)')

# %%
for galaxy,color in zip(uniq_gal,colors):
    galaxy_data=combined_df[combined_df['Galaxy']==galaxy]
    plt.scatter(galaxy_data['Rad'],galaxy_data['Vgas'],color=color)

# %%
def vdisk(r,sigma0,rd):
    const=4*np.pi*sigma0*rd
    sec=i0(r/(2*rd))*k0(r/(2*rd))-i1(r/(2*rd))*k1(r/(2*rd))
    temp=1e-3*np.sqrt(np.abs(c*(r/(2*rd))**2*sec))
    return temp

# %%
r_d=2.18*kpc
s_0=(10205.4*msun)/(pc**2)
bounds=((0.1*s_0,0.1*r_d),(10*s_0,10*r_d))
popt,pcov=curve_fit(vdisk,combined_df['Rad']*kpc,combined_df['Vdisk'],p0=(0.5*s_0,r_d),bounds=bounds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 4
#       2 s_0=(10205.4*msun)/(pc**2)
#       3 bounds=((0.1*s_0,0.1*r_d),(10*s_0,10*r_d))
# ----> 4 popt,pcov=curve_fit(vdisk,combined_df['Rad']*kpc,combined_df['Vdisk'],p0=(0.5*s_0,r_d),bounds=bounds)
#
# File ~/Documents/jupyter-env/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:902, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     900 # optimization may produce garbage for float32 inputs, cast them to float64
#     901 if check_finite:
# --> 902     ydata = np.asarray_chkfinite(ydata, float)
#     903 else:
#     904     ydata = np.asarray(ydata, float)
#
# File ~/Documents/jupyter-env/lib/python3.10/site-packages/numpy/lib/function_base.py:630, in asarray_chkfinite(a, dtype, order)
#     628 a = asarray(a, dtype=dtype, order=order)
#     629 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 630     raise ValueError(
#     631         "array must not contain infs or NaNs")
#     632 return a
#
# ValueError: array must not contain infs or NaNs

# %%
combined_df[combined_df['Vdisk']=='NaN']
# Out:
# Empty DataFrame
# Columns: [Rad, Vobs, errV, Vgas, Vdisk, Vbul, SBdisk, SBbul, Galaxy]
# Index: []
